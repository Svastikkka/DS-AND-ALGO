# %%
from kiteconnect import KiteConnect
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
import time
import os
from pyotp import TOTP

def autologin():
    token_path = "api_key.txt"
    key_secret = open(token_path, 'r').read().split()
    
    kite = KiteConnect(api_key=key_secret[0])
    
    # Set up Chrome options
    options = webdriver.ChromeOptions()
    # Uncomment the next line to run headless
    # options.add_argument('--headless')
    
    # Create a service object
    service = ChromeService(executable_path='./chromedriver')
    service.start()
    
    # Create a new instance of the Chrome driver
    driver = webdriver.Chrome(service=service, options=options)
    
    driver.get(kite.login_url())
    driver.implicitly_wait(10)
    
    # Enter username and password
    username = driver.find_element(By.XPATH, '//*[@id="userid"]')  # Updated XPath
    password = driver.find_element(By.XPATH, '//*[@id="password"]')  # Updated XPath
    username.send_keys(key_secret[2])
    password.send_keys(key_secret[3])
    
    # Click on the login button
    driver.find_element(By.XPATH, '//button[@type="submit"]').click()
    
    # Enter TOTP
    time.sleep(5)  # Wait for the PIN input to appear
    pin = driver.find_element(By.XPATH, '//*[@id="userid"]')  # Updated XPath
    totp = TOTP(key_secret[4])
    token = totp.now()
    pin.send_keys(token)
    
    # Click on the submit button
    driver.find_element(By.XPATH, '//button[@type="submit"]').click()
    
    # Wait for the redirect
    time.sleep(10)
    
    # Extract request token from the URL
    request_token = driver.current_url.split('request_token=')[1][:32]
    with open('request_token.txt', 'w') as the_file:
        the_file.write(request_token)
    
    driver.quit()

autologin()


autologin()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[10], line 59
#      55         the_file.write(request_token)
#      57     driver.quit()
# ---> 59 autologin()
#      62 autologin()
#
# Cell In[10], line 43, in autologin()
#      41 pin = driver.find_element(By.XPATH, '//*[@id="userid"]')  # Updated XPath
#      42 totp = TOTP(key_secret[4])
# ---> 43 token = totp.now()
#      44 pin.send_keys(token)
#      46 # Click on the submit button
#
# File ~/miniconda3/envs/algo/lib/python3.8/site-packages/pyotp/totp.py:64, in TOTP.now(self)
#      58 def now(self) -> str:
#      59     """
#      60     Generate the current time OTP
#      61
#      62     :returns: OTP value
#      63     """
# ---> 64     return self.generate_otp(self.timecode(datetime.datetime.now()))
#
# File ~/miniconda3/envs/algo/lib/python3.8/site-packages/pyotp/otp.py:35, in OTP.generate_otp(self, input)
#      33 if input < 0:
#      34     raise ValueError("input must be positive integer")
# ---> 35 hasher = hmac.new(self.byte_secret(), self.int_to_bytestring(input), self.digest)
#      36 hmac_hash = bytearray(hasher.digest())
#      37 offset = hmac_hash[-1] & 0xF
#
# File ~/miniconda3/envs/algo/lib/python3.8/site-packages/pyotp/otp.py:52, in OTP.byte_secret(self)
#      50 if missing_padding != 0:
#      51     secret += "=" * (8 - missing_padding)
# ---> 52 return base64.b32decode(secret, casefold=True)
#
# File ~/miniconda3/envs/algo/lib/python3.8/base64.py:231, in b32decode(s, casefold, map01)
#     229             acc = (acc << 5) + b32rev[c]
#     230     except KeyError:
# --> 231         raise binascii.Error('Non-base32 digit found') from None
#     232     decoded += acc.to_bytes(5, 'big')
#     233 # Process the last, partial quanta
#
# Error: Non-base32 digit found
