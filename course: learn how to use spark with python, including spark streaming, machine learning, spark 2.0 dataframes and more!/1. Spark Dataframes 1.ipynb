# %% [markdown]
# # Spark Data Frames

# %%
import os
os.environ["JAVA_HOME"] = "/opt/homebrew/opt/openjdk@17"
os.environ["PATH"] = f"{os.environ['JAVA_HOME']}/bin:" + os.environ["PATH"]
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Basics").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/10/11 14:21:34 WARN Utils: Your hostname, Manshus-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.221.38.203 instead (on interface en0)
# 25/10/11 14:21:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/10/11 14:21:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/10/11 14:21:35 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df = spark.read.csv("../datasets/testing.csv", header=True, inferSchema=True)

# %%
df.show()
# Out:
# +----------------+-------------+
# |            Name|       Number|
# +----------------+-------------+
# |   Manshu Sharma|7.425033404E9|
# |Swayista T Ahmed| 9.87654321E8|
# |      Svastikkka|         NULL|
# +----------------+-------------+

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Number: double (nullable = true)

# %%
df.columns
# Out:
# ['Name', 'Number']

# %%
df.describe().show()
# Out:
# +-------+----------------+-------------------+
# |summary|            Name|             Number|
# +-------+----------------+-------------------+
# |  count|               3|                  2|
# |   mean|            NULL|     4.2063438625E9|
# | stddev|            NULL|4.551914402657739E9|
# |    min|   Manshu Sharma|       9.87654321E8|
# |    max|Swayista T Ahmed|      7.425033404E9|
# +-------+----------------+-------------------+

# %% [markdown]
# # Update Schema Defination

# %%
from pyspark.sql.types import (StructField, StructType, StringType, IntegerType)

# %%
data_schema=[StructField('Name', StringType(), True),
             StructField('Number', IntegerType(), True)]

# %%
final_struct = StructType(fields=data_schema)

# %%
df = spark.read.csv("../datasets/testing.csv", header=True, inferSchema=True, schema=final_struct)

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Number: integer (nullable = true)

# %%
df.show()
# Out:
# +----------------+------+
# |            Name|Number|
# +----------------+------+
# |   Manshu Sharma|     1|
# |Swayista T Ahmed|     2|
# |      Svastikkka|  NULL|
# +----------------+------+
