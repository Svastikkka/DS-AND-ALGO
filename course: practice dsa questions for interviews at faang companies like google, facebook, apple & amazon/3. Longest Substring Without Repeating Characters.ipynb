# %% [markdown]
# Given a string s, find the length of the longest substring without duplicate characters.

# %% [markdown]
# Example 1:
# - Input: s = "abcabcbb"
# - Output: 3
# - Explanation: The answer is "abc", with the length of 3.
#
# Example 2:
# - Input: s = "bbbbb"
# - Output: 1
# - Explanation: The answer is "b", with the length of 1.
#
# Example 3:
# - Input: s = "pwwkew"
# - Output: 3
# - Explanation: The answer is "wke", with the length of 3.
#
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.

# %% [markdown]
# Approach:
# 1. Use a set to store unique characters in the current window.
# 2. Use two pointers: left and right.
# 3. Expand right, and:
#     - If s[right] is not in the set, add it and update the max length.
#     - If s[right] is in the set, remove characters from the left until it’s not.
# 4. Keep track of the maximum window length.

# %%
s = "pwwkew"
left = 0
char_set = set()
max_len = 0
for right in s:
    if right in char_set:
        char_set.remove(s[left])
        left+=1
    char_set.add(s[right])
    max_len+=1
