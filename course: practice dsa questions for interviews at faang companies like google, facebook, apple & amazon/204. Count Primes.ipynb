# %% [markdown]
# Given an integer n, return the number of prime numbers that are strictly less than n.

# %% [markdown]
# Example 1:
# - Input: n = 10
# - Output: 4
# - Explanation: There are 4 prime numbers less than 10, they are 2, 3, 5, 7.
#
# Example 2:
# - Input: n = 0
# - Output: 0
#
# Example 3:
# - Input: n = 1
# - Output: 0

# %% [markdown]
# Approach:
# 1. Create a boolean array is_prime of size n initialized to True
# 2. Set is_prime[0] and is_prime[1] to False since 0 and 1 are not primes
# 3. For every number i starting from 2, mark its multiples as non-prime
# 4. Count the number of True values in is_prime

# %%
n=10
is_prime = [True]*10
is_prime[0]=False
is_prime[1]=False
for i in range(2,len(is_prime)):
    if is_prime[i]:
        for j in range(i*i,len(is_prime),i):
            is_prime[j]=False
print(sum(is_prime))
print(is_prime)
# Out:
# 4
# [False, False, True, True, False, True, False, True, False, False]
