# %% [markdown]
# # GRAPH

# %%
class Graph:
    def __init__(self,gdict=None):
        if gdict is None:
            gdict = {}
        self.gdict = gdict
    def addEdge(self, vertex, edge):
        self.gdict[vertex].append(edge)

customDict = {
    "a": ["b", "c"],
    "b": ["a", "d", "e"],
    "c": ["a", "e"],
    "d": ["b", "e", "f"],
    "e": ["d", "f"],
    "f": ["d", "e"]
}
graph = Graph(customDict)
graph.addEdge("e", "c")
print(graph.gdict)
# Out:
# {'a': ['b', 'c'], 'b': ['a', 'd', 'e'], 'c': ['a', 'e'], 'd': ['b', 'e', 'f'], 'e': ['d', 'f', 'c'], 'f': ['d', 'e']}

# %%
class Graph:
    def __init__(self):
        self.gdict = {}
    
    def add_vertex(self, vertex):
        if  vertex not in self.gdict.keys():
            self.gdict[vertex] = []
            return True
        return False
    
    def add_edge(self, vertex1, vertex2):
        if vertex1 in self.gdict.keys() and vertex2 in self.gdict.keys():
            self.gdict[vertex1].append(vertex2)
            self.gdict[vertex2].append(vertex1)
            return True
        return False
    
    def remove_edge(self,vertex1, vertex2):
        if vertex1 in self.gdict.keys() and vertex2 in self.gdict.keys():
            try:
                self.gdict[vertex1].remove(vertex2)
                self.gdict[vertex2].remove(vertex1)
            except:
                print("NO EDGE ATTACHED") # ADDED EXCEPTION HANDLING TO HANDLE VALUE ERROR
            return True
        return False
    
    def print_gdict(self):
        for vertex in self.gdict:
            print(vertex,": ",self.gdict[vertex])

graph = Graph()
graph.add_vertex("a")
graph.add_vertex("b")
graph.add_vertex("c")
graph.add_edge("a","b")
graph.add_edge("a","c")
graph.add_edge("c","b")
print(graph.print_gdict())
graph.remove_edge("a","b")
print(graph.print_gdict())
graph.add_vertex("d")
graph.remove_edge("a","d")
# Out:
# a :  ['b', 'c']
# b :  ['a', 'c']
# c :  ['a', 'b']
# None
# a :  ['c']
# b :  ['c']
# c :  ['a', 'b']
# None
# NO EDGE ATTACHED
# True

# %%
class Graph:
    def __init__(self):
        self.gdict = {}
    
    def add_vertex(self, vertex):
        if  vertex not in self.gdict.keys():
            self.gdict[vertex] = []
            return True
        return False
    
    def add_edge(self, vertex1, vertex2):
        if vertex1 in self.gdict.keys() and vertex2 in self.gdict.keys():
            self.gdict[vertex1].append(vertex2)
            self.gdict[vertex2].append(vertex1)
            return True
        return False
    
    def remove_edge(self,vertex1, vertex2):
        if vertex1 in self.gdict.keys() and vertex2 in self.gdict.keys():
            try:
                self.gdict[vertex1].remove(vertex2)
                self.gdict[vertex2].remove(vertex1)
            except:
                print("NO EDGE ATTACHED") # ADDED EXCEPTION HANDLING TO HANDLE VALUE ERROR
            return True
        return False

    def remove_vertex(self,vertex):
        if vertex in self.gdict.keys():
            temp_list = self.gdict[vertex].copy() # USE copy() YOU ARE TELLING SYSTEM TO TAKE A COPY AND THEN PERFORM OPERATION
            for i in temp_list:
                print(i)
                self.remove_edge(vertex,i)

    def print_gdict(self):
        for vertex in self.gdict:
            print(vertex,": ",self.gdict[vertex])

graph = Graph()
graph.add_vertex("a")
graph.add_vertex("b")
graph.add_vertex("c")
graph.add_edge("a","b")
graph.add_edge("a","c")
graph.add_edge("c","b")
print(graph.print_gdict())
graph.remove_edge("a","b")
print(graph.print_gdict())
graph.add_vertex("d")
graph.add_edge("a","d")
graph.add_edge("b","d")
print(graph.print_gdict())
graph.remove_vertex("d")
print(graph.print_gdict())
# Out:
# a :  ['b', 'c']
# b :  ['a', 'c']
# c :  ['a', 'b']
# None
# a :  ['c']
# b :  ['c']
# c :  ['a', 'b']
# None
# a :  ['c', 'd']
# b :  ['c', 'd']
# c :  ['a', 'b']
# d :  ['a', 'b']
# None
# a
# b
# a :  ['c']
# b :  ['c']
# c :  ['a', 'b']
# d :  []
# None
