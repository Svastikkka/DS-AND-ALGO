# %% [markdown]
# # Indicators

# %% [markdown]
# #### Lagging Indicators
# 1. Moving Average
# 2. MACD
# #### Osicilators
# #### Leading Indicators

# %% [markdown]
# ## 1. Moving Averages

# %% [markdown]
# ## 2. MACD

# %% [markdown]
# ## 1. Relative Strength Indicators (RSI)
